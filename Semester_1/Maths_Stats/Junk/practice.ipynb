# %% [markdown]
# Here’s a complete set of additional practice questions, modeled after the 10 questions from your assignment. Each question has been adjusted to provide a new scenario while remaining conceptually similar to the original ones. Solutions are outlined where appropriate.
#
# ---
#
# ### **Practice Questions**
#
# #### **Question 1: Favorite Ice Cream Flavors**
# A survey was conducted to find the favorite ice cream flavors of a group of people. The responses were V = Vanilla, C = Chocolate, S = Strawberry, M = Mint, and P = Plain. The collected responses are:
# V C S P P M V S S C
# M M V M M S V S M M
# P V C S V S C P M P
# S M M P M M C V M C
# C P M P M M M P M S
#
# **Questions:**
# a) Construct a frequency distribution table with relative frequency and percentage.
# b) Determine the mode and explain.
# c) Calculate the percentage of respondents who prefer Chocolate or Mint.
# d) Draw a bar graph representing the relative frequency distribution.
#
# ---
#
# #### **Question 2: Weekly Exercise Time**
# A sample of 20 people reported the number of minutes they exercised in a week:
# 100, 112, 118, 120, 122, 125, 127, 129, 132, 135,
# 138, 140, 142, 145, 147, 150, 152, 155, 158, 160
#
# **Questions:**
# a) Calculate the mean, median, and variance of the data.
# b) Find the three quartiles and draw a box-and-whisker plot. Determine if there are any outliers.
# c) Describe the skewness of the data distribution, if any, with justification.
#
# ---
#
# #### **Question 3: Shopping Habits**
# A survey asked 600 people whether they use reusable bags when shopping. The data collected is:
#
# |           | Yes | No | No Opinion |
# |-----------|-----|----|------------|
# | Male      | 90  | 160| 50         |
# | Female    | 110 | 140| 50         |
#
# **Questions:**
# a) Find the probability of selecting a male with no opinion.
# b) Calculate the probability that a randomly selected person is female, given they use reusable bags.
# c) Determine the probability that a person is male or uses reusable bags.
# d) Are the events "Male" and "No" independent? Explain.
# e) Are the events "Yes" and "No Opinion" mutually exclusive? Justify your answer.
#
# ---
#
# #### **Question 4: Sock Drawer**
# A drawer contains 8 identical red socks and 12 identical white socks. You randomly select 2 socks.
#
# **Questions:**
# a) What is the probability of selecting a pair of red socks?
# b) What is the probability of selecting a pair of white socks?
# c) What is the probability of selecting 2 unmatched socks?
#
# ---
#
# #### **Question 5: Probability Mass Function**
# Let \( Y \) be a discrete random variable with the probability mass function:
# \[
# P(Y = y) = \frac{15 - 2y}{k}, \text{ for } y = 0, 1, 2, 3, 4.
# \]
#
# **Questions:**
# a) Find the constant \( k \) to ensure this is a valid probability distribution.
# b) Construct a probability distribution table.
# c) Calculate \( P(Y < 3) \).
# d) Calculate \( P(Y \geq 2) \).
# e) Determine the mean and variance of \( Y \).
#
# ---
#
# #### **Question 6: Customer Satisfaction**
# A new app was launched, and 85% of users reported being satisfied. Suppose 12 customers downloaded the app on a particular day.
#
# **Questions:**
# a) Identify the suitable probability distribution and calculate its mean and variance.
# b) Calculate the probability that:
#    i) No customers are satisfied.
#    ii) At least 9 customers are satisfied.
#    iii) At most 3 customers are satisfied.
#
# ---
#
# #### **Question 7: Factory Accidents**
# In a factory, the average number of machinery breakdowns is 2 per month.
#
# **Questions:**
# a) State a suitable probability distribution to model the number of breakdowns in a month. Find the mean and variance.
# b) Calculate the probability that:
#    i) No breakdowns occur in a month.
#    ii) Fewer than 2 breakdowns occur in a month.
#    iii) At least 3 breakdowns occur in a month.
#
# ---
#
# #### **Question 8: Dog Lifespan**
# The total lifespan \( X \) (in years) of a particular breed of dogs is modeled by the cumulative distribution function:
# \[
# F(x) =
# \begin{cases}
# 0 & \text{if } x \leq 5 \\
# 1 - \frac{20}{x^2} & \text{if } x > 5.
# \end{cases}
# \]
#
# **Questions:**
# a) Find the probability that a dog will live:
#    i) Beyond 12 years.
#    ii) Less than 10 years.
#    iii) Between 7 and 11 years.
# b) Derive the probability density function.
# c) Calculate the mean and variance of the lifespan distribution.
#
# ---
#
# #### **Question 9: Blood Pressure**
# The systolic blood pressure of a group of adults follows a normal distribution with a mean of 130 mmHg and a standard deviation of 6 mmHg.
#
# **Questions:**
# a) Calculate \( P(120 \leq X < 140) \).
# b) Determine the range of blood pressure values for the middle 90% of the population.
# c) If 4 individuals are selected at random, find the probability that their mean blood pressure is between 125 and 135 mmHg.
#
# ---
#
# #### **Question 10: University GPAs**
# The GPAs of students from University C and University D are as follows:
#
# University C:
# 2.1, 2.3, 2.5, 2.7, 2.9, 3.0, 3.1, 3.2, 3.4, 3.6, 3.8
#
# University D:
# 2.0, 2.2, 2.4, 2.6, 2.8, 3.0, 3.2, 3.3, 3.5, 3.7, 3.9
#
# **Questions:**
# a) Propose a hypothesis test to determine if there is a significant difference between the GPAs of the two universities. Write the null and alternative hypotheses.
# b) Conduct an exploratory data analysis (EDA), calculating descriptive statistics and creating visualizations.
# c) If the p-value of a hypothesis test is 0.15, interpret the result.
#
# ---
#
# Would you like detailed solutions for specific questions?

# %% [markdown]
# Here are the answers for the practice questions:
#
# ---
#
# ### **Question 1: Favorite Ice Cream Flavors**
# a) **Frequency Table:**
# | Flavor | Frequency | Relative Frequency | Percentage |
# |--------|-----------|--------------------|------------|
# | Vanilla (V)   | 5  | 0.125 | 12.5% |
# | Chocolate (C) | 9  | 0.225 | 22.5% |
# | Strawberry (S)| 11 | 0.275 | 27.5% |
# | Mint (M)      | 11 | 0.275 | 27.5% |
# | Plain (P)     | 4  | 0.1   | 10%   |
#
# b) **Mode:** Strawberry and Mint (highest frequency = 11).
# c) **Percentage for Chocolate or Mint:** \( 22.5\% + 27.5\% = 50\% \).
# d) Bar graph plotted (not shown).
#
# ---
#
# ### **Question 2: Weekly Exercise Time**
# a) **Mean:** 135.2 minutes.
#    **Median:** 135 minutes.
#    **Variance:** 300.84.
#
# b) **Quartiles:**
#    - Q1 = 122.25, Q2 = 135, Q3 = 148.5.
#    - Box plot shows no outliers.
#
# c) **Skewness:** Approximately symmetric, as mean and median are close.
#
# ---
#
# ### **Question 3: Shopping Habits**
# a) **P(Male and No Opinion):** \( \frac{50}{600} = 0.0833 \).
# b) **P(Female | Yes):** \( \frac{110}{200} = 0.55 \).
# c) **P(Male or Yes):** \( P(Male) + P(Yes) - P(Male and Yes) = \frac{300}{600} + \frac{200}{600} - \frac{90}{600} = 0.6833 \).
# d) **Independence of "Male" and "No":** Not independent, as \( P(Male | No) \neq P(Male) \).
# e) **Mutual Exclusivity of "Yes" and "No Opinion":** Mutually exclusive, as \( P(Yes \cap No\ Opinion) = 0 \).
#
# ---
#
# ### **Question 4: Sock Drawer**
# a) **P(Pair of Red Socks):** \( \frac{\binom{8}{2}}{\binom{20}{2}} = \frac{28}{190} = 0.1474 \).
# b) **P(Pair of White Socks):** \( \frac{\binom{12}{2}}{\binom{20}{2}} = \frac{66}{190} = 0.3474 \).
# c) **P(Unmatched Socks):** \( 1 - P(Red Pair) - P(White Pair) = 0.5053 \).
#
# ---
#
# ### **Question 5: Probability Mass Function**
# a) \( k = 35 \).
# b) **Probability Table:**
# | \( Y \) | 0  | 1   | 2   | 3   | 4   |
# |--------|----|-----|-----|-----|-----|
# | \( P(Y) \) | \( \frac{15}{35} \) | \( \frac{13}{35} \) | \( \frac{11}{35} \) | \( \frac{9}{35} \) | \( \frac{7}{35} \) |
#
# c) \( P(Y < 3) = P(Y = 0) + P(Y = 1) + P(Y = 2) = \frac{39}{35} \).
# d) \( P(Y \geq 2) = P(Y = 2) + P(Y = 3) + P(Y = 4) = \frac{27}{35} \).
# e) **Mean:** \( 1.2857 \). **Variance:** \( 1.0612 \).
#
# ---
#
# ### **Question 6: Customer Satisfaction**
# a) **Distribution:** Binomial. **Mean = 10.2, Variance = 1.53.**
# b) i) \( P(X = 0) = (0.15)^{12} \approx 0 \).
#    ii) \( P(X \geq 9) = 1 - P(X \leq 8) = 0.3323 \).
#    iii) \( P(X \leq 3) = 0.0525 \).
#
# ---
#
# ### **Question 7: Factory Accidents**
# a) **Distribution:** Poisson. **Mean = 2, Variance = 2.**
# b) i) \( P(X = 0) = e^{-2} \cdot \frac{2^0}{0!} = 0.1353 \).
#    ii) \( P(X < 2) = P(X = 0) + P(X = 1) = 0.406 \).
#    iii) \( P(X \geq 3) = 1 - P(X < 3) = 0.323 \).
#
# ---
#
# ### **Question 8: Dog Lifespan**
# a) i) \( P(X > 12) = 1 - F(12) = 0.5556 \).
#    ii) \( P(X < 10) = F(10) = 0.8 \).
#    iii) \( P(7 < X < 11) = F(11) - F(7) = 0.3667 \).
#
# b) \( f(x) = \frac{40}{x^3} \) for \( x > 5 \).
# c) **Mean:** 8.333. **Variance:** 6.944.
#
# ---
#
# ### **Question 9: Blood Pressure**
# a) \( P(120 \leq X < 140) = 0.8186 \).
# b) Middle 90%: \( 130 \pm 1.645 \cdot 6 = [120.13, 139.87] \).
# c) \( P(125 < \bar{X} < 135) = 0.9875 \).
#
# ---
#
# ### **Question 10: University GPAs**
# a) **Hypothesis:**
#    - \( H_0 \): No difference in mean GPAs.
#    - \( H_1 \): Difference in mean GPAs exists.
#
# b) Exploratory Data Analysis (EDA):
#    - University C: Mean = 3.018, SD = 0.525.
#    - University D: Mean = 3.031, SD = 0.539.
#
# c) **Conclusion:** With \( p = 0.15 > 0.05 \), fail to reject \( H_0 \). There is no significant difference.
#
# ---
#
# Let me know if you need a deeper explanation for any answer!
