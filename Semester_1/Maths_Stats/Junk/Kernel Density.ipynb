# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Generate sample data
data = np.concatenate([np.random.normal(loc=-2, scale=0.5, size=300),
                       np.random.normal(loc=2, scale=0.5, size=300)])

# Create KDE plot
sns.kdeplot(data, bw_adjust=0.5, fill=True)
plt.title("Kernel Density Estimation")
plt.xlabel("Data Values")
plt.ylabel("Density")
plt.show()

# %%
test = [73,75,69,68,78,69,74,76,72,79,68,77,71]
np.quantile(test,0.25), np.quantile(test,0.5), np.quantile(test,0.75)
np.iqr(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 test = [73,75,69,68,78,69,74,76,72,79,68,77,71]
#       2 np.quantile(test,0.25), np.quantile(test,0.5), np.quantile(test,0.75)
# ----> 3 np.iqr(test)
#
# File c:\Users\PC03\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'iqr'

# %%
np.sort(test)
# Out:
# array([68, 68, 69, 69, 71, 72, 73, 74, 75, 76, 77, 78, 79])

# %%
plt.boxplot(data=test, x=test, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dff8c4a240>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dff8c4a840>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dff8c49fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dff8c4ae40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dff8c4b140>],
#  'means': []}

# %%
ranked_data = [69,74,75,79,81,84,90,94,98,104,112,144]
q1 = np.quantile(ranked_data,0.25)
q2 = np.quantile(ranked_data, 0.5)
q3 = np.quantile(ranked_data,0.75)
print(f'''
Q1 = {q1}
Q2 = {q2}
Q3 = {q3}
      ''')

# %%
plt.boxplot(data = ranked_data, x=ranked_data, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dff8c747a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dff8c74590>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dff8c77f20>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dff8c779e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dff8c75370>],
#  'means': []}

# %%
import pandas as pd
wood = [50,56,60,48,35,67,72,68]
steel = [55,70,48,28,100,106,102,120]
cons = pd.DataFrame({"Wood" : wood,"Steel" : steel})
cons_melted = pd.melt(cons, var_name="Material", value_name="Quantity")
cons_melted
# Out:
#    Material  Quantity
# 0      Wood        50
# 1      Wood        56
# 2      Wood        60
# 3      Wood        48
# 4      Wood        35
# 5      Wood        67
# 6      Wood        72
# 7      Wood        68
# 8     Steel        55
# 9     Steel        70
# 10    Steel        48
# 11    Steel        28
# 12    Steel       100
# 13    Steel       106
# 14    Steel       102
# 15    Steel       120

# %%
plt.boxplot(data = cons, x="material", )
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.boxplot(data = cons, x="material")
#
# File c:\Users\PC03\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2848, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2816 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2817 def boxplot(
#    2818     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    2846     data=None,
#    2847 ) -> dict[str, Any]:
# -> 2848     return gca().boxplot(
#    2849         x,
#    2850         notch=notch,
#    2851         sym=sym,
#    2852         vert=vert,
#    2853         whis=whis,
# ...

# %%
test = [27,27,28,36,38,40,40,43,43,48,50,58,62,72,77,84,86,86,90,94]
test2 = 0
for i in test:
    x = i**2
    print(x)
    test2 += x
print(test2)
# Out:
# 729
# 729
# 784
# 1296
# 1444
# 1600
# 1600
# 1849
# 1849
# 2304
# 2500
# 3364
# 3844
# 5184
# 5929
# 7056
# 7396
# 7396
# 8100
# 8836
# 73789

# %%
plut = [62,67,72,73,75,77,81,83,84,85,90,93,107,112,135]
sum()
plt.boxplot(data=plut, x=plut, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dff8d0e1e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dff8d0e960>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dff8d0fc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dff8d0f4d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dff8e240e0>],
#  'means': []}

# %%
sum(plut)
# Out:
# 1296

# %%
q1 = np.quantile(plut,0.25)
q2 = np.quantile(plut, 0.5)
q3 = np.quantile(plut,0.75)
print(f'''
Q1 = {q1}
Q2 = {q2}
Q3 = {q3}
      ''')
# Out:
# Q1 = 74.0
# Q2 = 83.0
# Q3 = 91.5

# %%
import random

# %%
random.binom
