# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_parquet('G:/My Drive/Master-Data-Science/Semester_1/Data_Mining/Projek/DataSet/bedutil_02_timeseries_facility.parquet')

# %%
data.head()
# Out:
#          date                              hospital  state  beds_nonicu  \
# 0  2023-09-07         Hospital Sultanah Nora Ismail  Johor        598.0
# 1  2023-09-07              Hospital Sultanah Aminah  Johor        969.0
# 2  2023-09-07                       Hospital Permai  Johor       1132.0
# 3  2023-09-07    Hospital Sultan Ismail Johor Bahru  Johor        653.0
# 4  2023-09-07  Hospital Enche' Besar Hajjah Khalsom  Johor        372.0
#
#    util_nonicu  beds_icu   util_icu  vent  util_vent
# 0    78.929766      12.0  83.333333  51.0  19.607843
# 1   111.145511      30.0  86.666667  75.0  54.666667
# 2    53.091873       0.0        NaN   0.0        NaN
# 3   118.683002      24.0  79.166667  45.0  42.222222
# 4    97.043011      10.0   0.000000  45.0   0.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52746 entries, 0 to 52745
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         52746 non-null  object
#  1   hospital     52746 non-null  object
#  2   state        52746 non-null  object
#  3   beds_nonicu  44466 non-null  float64
#  4   util_nonicu  43215 non-null  float64
#  5   beds_icu     44467 non-null  float64
#  6   util_icu     21442 non-null  float64
#  7   vent         44467 non-null  float64
#  8   util_vent    24070 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 3.6+ MB

# %%
data['date'] = pd.to_datetime(data['date'])
data['state'] = data['state'].astype('category')
data['hospital'] = data['hospital'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52746 entries, 0 to 52745
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         52746 non-null  datetime64[ns]
#  1   hospital     52746 non-null  category
#  2   state        52746 non-null  category
#  3   beds_nonicu  44466 non-null  float64
#  4   util_nonicu  43215 non-null  float64
#  5   beds_icu     44467 non-null  float64
#  6   util_icu     21442 non-null  float64
#  7   vent         44467 non-null  float64
#  8   util_vent    24070 non-null  float64
# dtypes: category(2), datetime64[ns](1), float64(6)
# memory usage: 3.0 MB

# %%
data_sort.head(50)
# Out:
#             date                           hospital  state  beds_nonicu  \
# 64    2023-09-07  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 213   2023-09-08  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 362   2023-09-09  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 511   2023-09-10  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 660   2023-09-11  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 809   2023-09-12  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 958   2023-09-16  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 1107  2023-09-17  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 1256  2023-09-18  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 1405  2023-09-19  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 1554  2023-09-20  Pusat Perubatan Universiti Malaya  Perak       1064.0
# 1703  2023-09-21  Pusat Perubatan Universiti Malaya  Perak       1064.0
# ...

# %%
data_sort = data.sort_values(by=['hospital', 'date'])
data_sort.head()
# Out:
#           date                          hospital  state  beds_nonicu  \
# 64  2023-09-07  Hospital  Raja Permaisuri Bainun  Perak       1064.0
# 213 2023-09-08  Hospital  Raja Permaisuri Bainun  Perak       1064.0
# 362 2023-09-09  Hospital  Raja Permaisuri Bainun  Perak       1064.0
# 511 2023-09-10  Hospital  Raja Permaisuri Bainun  Perak       1064.0
# 660 2023-09-11  Hospital  Raja Permaisuri Bainun  Perak       1064.0
#
#      util_nonicu  beds_icu   util_icu  vent  util_vent
# 64     79.323308      33.0  84.848485  86.0  75.581395
# 213    77.913534      33.0  84.848485  86.0  74.418605
# 362    75.939850      33.0  75.757576  86.0  76.744186
# 511    70.676692      33.0  84.848485  86.0  77.906977
# 660    75.375940      33.0  87.878788  86.0  79.069767

# %%
test_data = data_sort.fillna(method='ffill')
test_data.head()
# Out:
# C:\Users\Hathim\AppData\Local\Temp\ipykernel_972\2203605252.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   test_data = data_sort.fillna(method='ffill')
#           date                          hospital  state  beds_nonicu  \
# 64  2023-09-07  Hospital  Raja Permaisuri Bainun  Perak       1064.0
# 213 2023-09-08  Hospital  Raja Permaisuri Bainun  Perak       1064.0
# 362 2023-09-09  Hospital  Raja Permaisuri Bainun  Perak       1064.0
# 511 2023-09-10  Hospital  Raja Permaisuri Bainun  Perak       1064.0
# 660 2023-09-11  Hospital  Raja Permaisuri Bainun  Perak       1064.0
#
#      util_nonicu  beds_icu   util_icu  vent  util_vent
# 64     79.323308      33.0  84.848485  86.0  75.581395
# 213    77.913534      33.0  84.848485  86.0  74.418605
# 362    75.939850      33.0  75.757576  86.0  76.744186
# 511    70.676692      33.0  84.848485  86.0  77.906977
# ...

# %%
data.sort_values(by=['state', 'date'], inplace=True)
hosp_list = pd.DataFrame({
    'state': [],
    'hospital': []
})

for state in data['state'].unique():
    for i in data[data['state'] == state].hospital.unique():
        new_row = pd.DataFrame({'state': [state], 'hospital': [i]})
        hosp_list = pd.concat([hosp_list, new_row], ignore_index=True)

hosp_list
# Out:
#                  state                                 hospital
# 0                Johor            Hospital Sultanah Nora Ismail
# 1                Johor                 Hospital Sultanah Aminah
# 2                Johor                          Hospital Permai
# 3                Johor       Hospital Sultan Ismail Johor Bahru
# 4                Johor     Hospital Enche' Besar Hajjah Khalsom
# ..                 ...                                      ...
# 144  W.P. Kuala Lumpur  Hospital Universiti Kebangsaan Malaysia
# 145  W.P. Kuala Lumpur        Pusat Perubatan Universiti Malaya
# 146        W.P. Labuan                          Hospital Labuan
# 147     W.P. Putrajaya                       Hospital Putrajaya
# 148     W.P. Putrajaya                   Institut Kanser Negara
#
# [149 rows x 2 columns]

# %%
hosp_list.hospital.duplicated().sum()
# Out:
# 0
